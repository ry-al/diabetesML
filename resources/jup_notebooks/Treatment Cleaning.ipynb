# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import time

# Google API Key
from config import gkey

# %% [markdown]
# # GETTING DATA

# %% [markdown]
# ### This is a csv of 1,673 clinics that are recognized or are in the process of being recognized as diabetes treatment centers.

# %%
# read csv
treatment = pd.read_csv("../data/DPRP_Results_Full_RegistryAug_05_2020.csv",encoding='cp1252')
treatment.head()

# %%
# add lat and lng columns
treatment['Lat'] = ""
treatment['Lng'] = ""

# check number of rows
treatment.shape

# %% [markdown]
# # START OF API CALL

# %%
# keep a counter
count = 0
set_num = 0

# for loop to iterate through rows
for index, row in treatment.iterrows():
    row = row.copy() 
    address = row['Address Line 1']
    
    # address doesn't work for suites, and prob po box, and some other types of addresses so expect to see it in errors.
    params = {"address": address,"key": gkey}
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    response = requests.get(base_url, params=params).json()
    
    # pull the lat and lng for df and print any that don't have 
    try:
        lat = response["results"][0]["geometry"]["location"]["lat"]
        lng = response["results"][0]["geometry"]["location"]["lng"]
        treatment.loc[index, 'Lat'] = lat
        treatment.loc[index, 'Lng'] = lng
    except IndexError:
        print(f"{index} - '{address}' not found. Skipping ... ")
        continue
    
    # add a time sleep
    if response == 45:
        t1 = time.time()
        count += 1
        set_num +=1
        time.sleep(60-(t1-t0))
        t0 = time.time()

# %% [markdown]
# # END OF API CALL

# %% [markdown]
# # SAVING NEW DF TO CSV

# %%
# checking that all that went through
treatment.head()
treatment.tail()

#checking how many rows have post api call
treatment.shape

# %% [markdown]
# ## DON'T RUN THIS IT'S ALREADY SAVED
# ### save new df to csv. remove index & keep the header
# treatment.to_csv("output/treatment_coord.csv", index=False, header=True)

# %% [markdown]
# # CLEANING NEW CSV

# %%
# read new csv
treatment_coord = pd.read_csv("output/treatment_coord.csv")
treatment_coord.head()
# Out:
#                                                 Name  \
# 0               Anchorage Neighborhood Health Center
# 1  University of Alaska Fairbanks Cooperative Ext...
# 2                                  YMCA of Anchorage
# 3                           Tanana Chiefs Conference
# 4                           Tanana Chiefs Conference
#
#                      Address Line 1       Address Line 2        City State  \
# 0          4951 Business Park Blvd.                  NaN  Anchorage     AK
# 1                    1675 C Street                   NaN  Anchorage     AK
# 2            5353 Lake Otis Parkway                  NaN   Anchorage    AK
# 3  Chief Andrew Isaac Health Center  1717 West Cowles St  Fairbanks     AK
# 4                1717 W. Cowles St.                  NaN  Fairbanks     AK
#
#      Zip                       Phone  \
# 0  99503              (907) 743-7200
# 1  99501              (907) 786-6300
# 2  99507   (907) 563-3211  Ext: 104
# 3  99701  (907) 451-6682  Ext: 3768
# 4  99701  (907) 451-6682  Ext: 3890
#
#                                    Web Address Recognition Status  \
# 0                                          NaN            Pending
# 1  http://www.uaf.edu/ces/districts/anchorage/               Full
# 2                    http://www.ymcaalaska.org               Full
# 3                                          NaN        Preliminary
# 4                                          NaN        Preliminary
#
#               Class open To Delivery Mode        Lat         Lng
# 0   Public Employees Other      In-Person  61.175943 -149.887679
# 1                   Public      In-Person  61.205926 -149.886380
# 2                   Public      In-Person  61.172156 -149.834741
# 3  Employees Members Other      In-Person  64.832476 -147.745224
# 4                    Other    Combination  64.832514 -147.744362

# %%
# rename columns. keep lat and lng in cap title letter for tableau
treatment_coord = treatment_coord.rename(columns={"Name":"name",
                                        "Address Line 1": "address_line1",
                                        "Address Line 2": "address_line2",
                                        "City":"city","State":"state", "Zip":"zip","Phone":"phone",
                                        "Web Address": "website",
                                        "Recognition Status": "recognition_status",
                                        "Class open To": "patient_type",
                                        "Delivery Mode": "delivery_mode","Lat":"Latitude","Lng":"Longitude"})
treatment_coord.head()
# Out:
#                                                 name  \
# 0               Anchorage Neighborhood Health Center
# 1  University of Alaska Fairbanks Cooperative Ext...
# 2                                  YMCA of Anchorage
# 3                           Tanana Chiefs Conference
# 4                           Tanana Chiefs Conference
#
#                       address_line1        address_line2        city state  \
# 0          4951 Business Park Blvd.                  NaN  Anchorage     AK
# 1                    1675 C Street                   NaN  Anchorage     AK
# 2            5353 Lake Otis Parkway                  NaN   Anchorage    AK
# 3  Chief Andrew Isaac Health Center  1717 West Cowles St  Fairbanks     AK
# 4                1717 W. Cowles St.                  NaN  Fairbanks     AK
#
#      zip                       phone  \
# 0  99503              (907) 743-7200
# 1  99501              (907) 786-6300
# 2  99507   (907) 563-3211  Ext: 104
# 3  99701  (907) 451-6682  Ext: 3768
# 4  99701  (907) 451-6682  Ext: 3890
#
#                                        website recognition_status  \
# 0                                          NaN            Pending
# 1  http://www.uaf.edu/ces/districts/anchorage/               Full
# 2                    http://www.ymcaalaska.org               Full
# 3                                          NaN        Preliminary
# 4                                          NaN        Preliminary
#
#                patient_type delivery_mode   Latitude   Longitude
# 0   Public Employees Other      In-Person  61.175943 -149.887679
# 1                   Public      In-Person  61.205926 -149.886380
# 2                   Public      In-Person  61.172156 -149.834741
# 3  Employees Members Other      In-Person  64.832476 -147.745224
# 4                    Other    Combination  64.832514 -147.744362

# %%
# edit NaNs in address line 2 & website 
treatment_coord['address_line2'] = treatment_coord['address_line2'].fillna("None")
treatment_coord['website'] = treatment_coord['website'].fillna("Unavailable")
treatment_coord.head()
# Out:
#                                                 name  \
# 0               Anchorage Neighborhood Health Center
# 1  University of Alaska Fairbanks Cooperative Ext...
# 2                                  YMCA of Anchorage
# 3                           Tanana Chiefs Conference
# 4                           Tanana Chiefs Conference
#
#                       address_line1        address_line2        city state  \
# 0          4951 Business Park Blvd.                 None  Anchorage     AK
# 1                    1675 C Street                  None  Anchorage     AK
# 2            5353 Lake Otis Parkway                 None   Anchorage    AK
# 3  Chief Andrew Isaac Health Center  1717 West Cowles St  Fairbanks     AK
# 4                1717 W. Cowles St.                 None  Fairbanks     AK
#
#      zip                       phone  \
# 0  99503              (907) 743-7200
# 1  99501              (907) 786-6300
# 2  99507   (907) 563-3211  Ext: 104
# 3  99701  (907) 451-6682  Ext: 3768
# 4  99701  (907) 451-6682  Ext: 3890
#
#                                        website recognition_status  \
# 0                                  Unavailable            Pending
# 1  http://www.uaf.edu/ces/districts/anchorage/               Full
# 2                    http://www.ymcaalaska.org               Full
# 3                                  Unavailable        Preliminary
# 4                                  Unavailable        Preliminary
#
#                patient_type delivery_mode   Latitude   Longitude
# 0   Public Employees Other      In-Person  61.175943 -149.887679
# 1                   Public      In-Person  61.205926 -149.886380
# 2                   Public      In-Person  61.172156 -149.834741
# 3  Employees Members Other      In-Person  64.832476 -147.745224
# 4                    Other    Combination  64.832514 -147.744362

# %%
# reorder columns to correspond with tableau's heirarchy
treatment_coord = treatment_coord[["name","address_line1","address_line2","city","state","zip","phone","Latitude","Longitude",
                                    "website","recognition_status","patient_type","delivery_mode"]]
treatment_coord.head()
# Out:
#                                                 name  \
# 0               Anchorage Neighborhood Health Center
# 1  University of Alaska Fairbanks Cooperative Ext...
# 2                                  YMCA of Anchorage
# 3                           Tanana Chiefs Conference
# 4                           Tanana Chiefs Conference
#
#                       address_line1        address_line2        city state  \
# 0          4951 Business Park Blvd.                 None  Anchorage     AK
# 1                    1675 C Street                  None  Anchorage     AK
# 2            5353 Lake Otis Parkway                 None   Anchorage    AK
# 3  Chief Andrew Isaac Health Center  1717 West Cowles St  Fairbanks     AK
# 4                1717 W. Cowles St.                 None  Fairbanks     AK
#
#      zip                       phone   Latitude   Longitude  \
# 0  99503              (907) 743-7200  61.175943 -149.887679
# 1  99501              (907) 786-6300  61.205926 -149.886380
# 2  99507   (907) 563-3211  Ext: 104   61.172156 -149.834741
# 3  99701  (907) 451-6682  Ext: 3768   64.832476 -147.745224
# 4  99701  (907) 451-6682  Ext: 3890   64.832514 -147.744362
#
#                                        website recognition_status  \
# 0                                  Unavailable            Pending
# 1  http://www.uaf.edu/ces/districts/anchorage/               Full
# 2                    http://www.ymcaalaska.org               Full
# 3                                  Unavailable        Preliminary
# 4                                  Unavailable        Preliminary
#
#                patient_type delivery_mode
# 0   Public Employees Other      In-Person
# 1                   Public      In-Person
# 2                   Public      In-Person
# 3  Employees Members Other      In-Person
# 4                    Other    Combination

# %%
# looking to see how class is split up...want to try to divide it by adding new rows...
treatment_coord["patient_type"].value_counts()
# Out:
# Public                             947
# Public Employees                   189
# Public Employees Members           109
# Employees                           93
# Other                               78
# Public Other                        56
# Members                             51
# Public Employees Other              44
# Public Employees Members Other      41
# Public Members                      19
# Employees Other                     17
# Employees Members                   13
# Employees Members Other              6
# Members Other                        6
# Public Members Other                 4
# Name: patient_type, dtype: int64

# %%
# splitting patient_type
treatment_split = pd.DataFrame(treatment_coord.patient_type.str.split(' ').tolist(), index=treatment_coord.name).stack()
# treatment_split

# %%
# reseting index in new df
treatment_split = treatment_split.reset_index([0, 'name'])
treatment_split
# Out:
#                                                    name          0
# 0                  Anchorage Neighborhood Health Center     Public
# 1                  Anchorage Neighborhood Health Center  Employees
# 2                  Anchorage Neighborhood Health Center      Other
# 3                  Anchorage Neighborhood Health Center
# 4     University of Alaska Fairbanks Cooperative Ext...     Public
# ...                                                 ...        ...
# 4090                          Powell Valley Health Care     Public
# 4091                          Powell Valley Health Care  Employees
# 4092                          Powell Valley Health Care
# 4093                        Goshen County Public Health     Public
# 4094                        Goshen County Public Health
#
# [4095 rows x 2 columns]

# %%
# renameing columns in new df
treatment_split.columns = ['name', 'patient_type']
treatment_split
# Out:
#                                                    name patient_type
# 0                  Anchorage Neighborhood Health Center       Public
# 1                  Anchorage Neighborhood Health Center    Employees
# 2                  Anchorage Neighborhood Health Center        Other
# 3                  Anchorage Neighborhood Health Center
# 4     University of Alaska Fairbanks Cooperative Ext...       Public
# ...                                                 ...          ...
# 4090                          Powell Valley Health Care       Public
# 4091                          Powell Valley Health Care    Employees
# 4092                          Powell Valley Health Care
# 4093                        Goshen County Public Health       Public
# 4094                        Goshen County Public Health
#
# [4095 rows x 2 columns]

# %%
# merge treatment_split & treatment_coord
treatment_combo = pd.merge(treatment_split, treatment_coord, on="name",how="outer")
treatment_combo.head()
# Out:
#                                                 name patient_type_x  \
# 0               Anchorage Neighborhood Health Center         Public
# 1               Anchorage Neighborhood Health Center      Employees
# 2               Anchorage Neighborhood Health Center          Other
# 3               Anchorage Neighborhood Health Center
# 4  University of Alaska Fairbanks Cooperative Ext...         Public
#
#               address_line1 address_line2        city state    zip  \
# 0  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 1  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 2  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 3  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 4            1675 C Street           None  Anchorage     AK  99501
#
#             phone   Latitude   Longitude  \
# 0  (907) 743-7200  61.175943 -149.887679
# 1  (907) 743-7200  61.175943 -149.887679
# 2  (907) 743-7200  61.175943 -149.887679
# 3  (907) 743-7200  61.175943 -149.887679
# 4  (907) 786-6300  61.205926 -149.886380
#
#                                        website recognition_status  \
# 0                                  Unavailable            Pending
# 1                                  Unavailable            Pending
# 2                                  Unavailable            Pending
# 3                                  Unavailable            Pending
# 4  http://www.uaf.edu/ces/districts/anchorage/               Full
#
#             patient_type_y delivery_mode
# 0  Public Employees Other      In-Person
# 1  Public Employees Other      In-Person
# 2  Public Employees Other      In-Person
# 3  Public Employees Other      In-Person
# 4                  Public      In-Person

# %%
# drop patient_type_y
treatment_combo = treatment_combo.drop(columns='patient_type_y')

# verify patient_type_y is dropped
treatment_combo.shape # output is:(4800, 13)
treatment_combo.head()
# Out:
#                                                 name patient_type_x  \
# 0               Anchorage Neighborhood Health Center         Public
# 1               Anchorage Neighborhood Health Center      Employees
# 2               Anchorage Neighborhood Health Center          Other
# 3               Anchorage Neighborhood Health Center
# 4  University of Alaska Fairbanks Cooperative Ext...         Public
#
#               address_line1 address_line2        city state    zip  \
# 0  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 1  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 2  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 3  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 4            1675 C Street           None  Anchorage     AK  99501
#
#             phone   Latitude   Longitude  \
# 0  (907) 743-7200  61.175943 -149.887679
# 1  (907) 743-7200  61.175943 -149.887679
# 2  (907) 743-7200  61.175943 -149.887679
# 3  (907) 743-7200  61.175943 -149.887679
# 4  (907) 786-6300  61.205926 -149.886380
#
#                                        website recognition_status  \
# 0                                  Unavailable            Pending
# 1                                  Unavailable            Pending
# 2                                  Unavailable            Pending
# 3                                  Unavailable            Pending
# 4  http://www.uaf.edu/ces/districts/anchorage/               Full
#
#   delivery_mode
# 0     In-Person
# 1     In-Person
# 2     In-Person
# 3     In-Person
# 4     In-Person

# %%
# drop any nulls
drop_it = treatment_combo.dropna(how="any")
drop_it #output is:(4673, 14)
# Out:
#                                                    name patient_type_x  \
# 0                  Anchorage Neighborhood Health Center         Public
# 1                  Anchorage Neighborhood Health Center      Employees
# 2                  Anchorage Neighborhood Health Center          Other
# 3                  Anchorage Neighborhood Health Center
# 4     University of Alaska Fairbanks Cooperative Ext...         Public
# ...                                                 ...            ...
# 4795                          Powell Valley Health Care         Public
# 4796                          Powell Valley Health Care      Employees
# 4797                          Powell Valley Health Care
# 4798                        Goshen County Public Health         Public
# 4799                        Goshen County Public Health
#
#                    address_line1 address_line2         city state    zip  \
# 0       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 1       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 2       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 3       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 4                 1675 C Street           None   Anchorage     AK  99501
# ...                          ...           ...          ...   ...    ...
# 4795                  777 Ave. H          None      Powell     WY  82435
# 4796                  777 Ave. H          None      Powell     WY  82435
# 4797                  777 Ave. H          None      Powell     WY  82435
# 4798  2025 Campbell Dr. Suite #1          None  Torrington     WY  82240
# 4799  2025 Campbell Dr. Suite #1          None  Torrington     WY  82240
#
#                            phone   Latitude   Longitude  \
# 0                 (907) 743-7200  61.175943 -149.887679
# 1                 (907) 743-7200  61.175943 -149.887679
# 2                 (907) 743-7200  61.175943 -149.887679
# 3                 (907) 743-7200  61.175943 -149.887679
# 4                 (907) 786-6300  61.205926 -149.886380
# ...                          ...        ...         ...
# 4795  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4796  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4797  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4798              (307) 532-4069  33.501088 -112.037390
# 4799              (307) 532-4069  33.501088 -112.037390
#
#                                           website recognition_status  \
# 0                                     Unavailable            Pending
# 1                                     Unavailable            Pending
# 2                                     Unavailable            Pending
# 3                                     Unavailable            Pending
# 4     http://www.uaf.edu/ces/districts/anchorage/               Full
# ...                                           ...                ...
# 4795                                  Unavailable            Pending
# 4796                                  Unavailable            Pending
# 4797                                  Unavailable            Pending
# 4798                                  Unavailable            Pending
# 4799                                  Unavailable            Pending
#
#      delivery_mode
# 0        In-Person
# 1        In-Person
# 2        In-Person
# 3        In-Person
# 4        In-Person
# ...            ...
# 4795     In-Person
# 4796     In-Person
# 4797     In-Person
# 4798     In-Person
# 4799     In-Person
#
# [4673 rows x 13 columns]

# %%
# rename patient_type_x
treatment1 = drop_it.rename(columns={"patient_type_x":"patient_type"})
treatment1
# Out:
#                                                    name patient_type  \
# 0                  Anchorage Neighborhood Health Center       Public
# 1                  Anchorage Neighborhood Health Center    Employees
# 2                  Anchorage Neighborhood Health Center        Other
# 3                  Anchorage Neighborhood Health Center
# 4     University of Alaska Fairbanks Cooperative Ext...       Public
# ...                                                 ...          ...
# 4795                          Powell Valley Health Care       Public
# 4796                          Powell Valley Health Care    Employees
# 4797                          Powell Valley Health Care
# 4798                        Goshen County Public Health       Public
# 4799                        Goshen County Public Health
#
#                    address_line1 address_line2         city state    zip  \
# 0       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 1       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 2       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 3       4951 Business Park Blvd.          None   Anchorage     AK  99503
# 4                 1675 C Street           None   Anchorage     AK  99501
# ...                          ...           ...          ...   ...    ...
# 4795                  777 Ave. H          None      Powell     WY  82435
# 4796                  777 Ave. H          None      Powell     WY  82435
# 4797                  777 Ave. H          None      Powell     WY  82435
# 4798  2025 Campbell Dr. Suite #1          None  Torrington     WY  82240
# 4799  2025 Campbell Dr. Suite #1          None  Torrington     WY  82240
#
#                            phone   Latitude   Longitude  \
# 0                 (907) 743-7200  61.175943 -149.887679
# 1                 (907) 743-7200  61.175943 -149.887679
# 2                 (907) 743-7200  61.175943 -149.887679
# 3                 (907) 743-7200  61.175943 -149.887679
# 4                 (907) 786-6300  61.205926 -149.886380
# ...                          ...        ...         ...
# 4795  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4796  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4797  (307) 754-2267  Ext: 3604   44.756996 -108.771452
# 4798              (307) 532-4069  33.501088 -112.037390
# 4799              (307) 532-4069  33.501088 -112.037390
#
#                                           website recognition_status  \
# 0                                     Unavailable            Pending
# 1                                     Unavailable            Pending
# 2                                     Unavailable            Pending
# 3                                     Unavailable            Pending
# 4     http://www.uaf.edu/ces/districts/anchorage/               Full
# ...                                           ...                ...
# 4795                                  Unavailable            Pending
# 4796                                  Unavailable            Pending
# 4797                                  Unavailable            Pending
# 4798                                  Unavailable            Pending
# 4799                                  Unavailable            Pending
#
#      delivery_mode
# 0        In-Person
# 1        In-Person
# 2        In-Person
# 3        In-Person
# 4        In-Person
# ...            ...
# 4795     In-Person
# 4796     In-Person
# 4797     In-Person
# 4798     In-Person
# 4799     In-Person
#
# [4673 rows x 13 columns]

# %%
# reorganize df
treatment1 = treatment1[["name","address_line1","address_line2","city","state","zip","phone","Latitude","Longitude",
                                    "website","recognition_status","patient_type","delivery_mode"]]
treatment1.head()
# Out:
#                                                 name  \
# 0               Anchorage Neighborhood Health Center
# 1               Anchorage Neighborhood Health Center
# 2               Anchorage Neighborhood Health Center
# 3               Anchorage Neighborhood Health Center
# 4  University of Alaska Fairbanks Cooperative Ext...
#
#               address_line1 address_line2        city state    zip  \
# 0  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 1  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 2  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 3  4951 Business Park Blvd.          None  Anchorage     AK  99503
# 4            1675 C Street           None  Anchorage     AK  99501
#
#             phone   Latitude   Longitude  \
# 0  (907) 743-7200  61.175943 -149.887679
# 1  (907) 743-7200  61.175943 -149.887679
# 2  (907) 743-7200  61.175943 -149.887679
# 3  (907) 743-7200  61.175943 -149.887679
# 4  (907) 786-6300  61.205926 -149.886380
#
#                                        website recognition_status  \
# 0                                  Unavailable            Pending
# 1                                  Unavailable            Pending
# 2                                  Unavailable            Pending
# 3                                  Unavailable            Pending
# 4  http://www.uaf.edu/ces/districts/anchorage/               Full
#
#   patient_type delivery_mode
# 0       Public     In-Person
# 1    Employees     In-Person
# 2        Other     In-Person
# 3                  In-Person
# 4       Public     In-Person

# %%
# remove empty cells
